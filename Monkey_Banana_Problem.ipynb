# %% [markdown]
# <a href="https://colab.research.google.com/github/ramprasanna007/artificial-intelligence/blob/main/Monkey_Banana_Problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Monkey Banana Problem

def monkey_banana():
    print("Monkey is on the floor.")

    print("Monkey moves the box under the banana.")

    print("Monkey climbs onto the box.")

    print("Monkey gets the banana.")

    print("Banana obtained!")

monkey_banana()
# Out:
# Monkey is on the floor.
# Monkey moves the box under the banana.
# Monkey climbs onto the box.
# Monkey gets the banana.
# Banana obtained!
