# %% [markdown]
# <a href="https://colab.research.google.com/github/ramprasanna007/artificial-intelligence/blob/main/Towers_of_Hanoi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Towers of Hanoi
def hanoi(n, from_peg, to_peg, aux_peg):

    # Base case: move one disk directly
    if n == 1:
        print("Move disk from", from_peg, "to", to_peg)
        return

    # Move n-1 disks from source to auxiliary
    hanoi(n - 1, from_peg, aux_peg, to_peg)

    # Move the largest disk from source to destination
    print("Move disk from", from_peg, "to", to_peg)

    # Move n-1 disks from auxiliary to destination
    hanoi(n - 1, aux_peg, to_peg, from_peg)


# Example: 3 disks
hanoi(3, 'A', 'C', 'B')
# Out:
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from A to C
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
