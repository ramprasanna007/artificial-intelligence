# %% [markdown]
# <a href="https://colab.research.google.com/github/ramprasanna007/artificial-intelligence/blob/main/Backward_chaining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Backward chaining

# %%
# -------------------------------
# Backward Chaining Example
# -------------------------------

# Facts stored in knowledge base
facts = {
    "Human(Socrates)"
}

# Rules stored as:
# conclusion : premise
rules = {
    "Mortal(Socrates)": "Human(Socrates)"
}

# Recursive backward chaining function
def backward_chain(goal):

    print(f"\nTrying to prove: {goal}")

    # Step 1: Check whether goal is already a fact
    if goal in facts:
        print(f"{goal} is a FACT.")
        return True

    # Step 2: Check if any rule can prove it
    if goal in rules:

        premise = rules[goal]

        print(f"Need to prove: {premise}")

        if backward_chain(premise):
            print(f"Rule applied:")
            print(f"{premise} --> {goal}")
            return True

    print(f"Cannot prove {goal}")
    return False


# Goal
goal = "Mortal(Socrates)"

print("Backward Chaining")

if backward_chain(goal):
    print("\nGoal PROVED")
else:
    print("\nGoal NOT PROVED")
# Out:
# Backward Chaining
#
# Trying to prove: Mortal(Socrates)
# Need to prove: Human(Socrates)
#
# Trying to prove: Human(Socrates)
# Human(Socrates) is a FACT.
# Rule applied:
# Human(Socrates) --> Mortal(Socrates)
#
# Goal PROVED

# %%
# Backward Chaining Example

# Known facts
facts = {"Study"}

# Rule: Pass requires Study
rules = {
    "Pass": "Study"
}

# Goal
goal = "Pass"

print("Goal:", goal)

if goal in rules:
    required_fact = rules[goal]
    print("Need to prove:", required_fact)

    if required_fact in facts:
        print("Fact found:", required_fact)
        print("Goal Proved")
    else:
        print("Goal Cannot Be Proved")
else:
    print("No rule available")
# Out:
# Goal: Pass
# Need to prove: Study
# Fact found: Study
# Goal Proved

# %%
# Backward Chaining Example

# Known facts
facts = {"rain"}

# Rule: carry umberalla requires rain
rules = {
    "carry umberalla": "rain"
}

# Goal
goal = "carry umberalla"

print("Goal:", goal)

if goal in rules:
    required_fact = rules[goal]
    print("Need to prove:", required_fact)

    if required_fact in facts:
        print("Fact found:", required_fact)
        print("Goal Proved")
    else:
        print("Goal Cannot Be Proved")
else:
    print("No rule available")
# Out:
# Goal: carry umberalla
# Need to prove: rain
# Fact found: rain
# Goal Proved
