# %% [markdown]
# <a href="https://colab.research.google.com/github/ramprasanna007/artificial-intelligence/blob/main/hanoi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hanoi(n, source, target, auxiliary):
    if n == 1:
        print("Move disk from", source, "to", target)
        return

    hanoi(n - 1, source, auxiliary, target)
    print("Move disk from", source, "to", target)
    hanoi(n - 1, auxiliary, target, source)

hanoi(3, 'A', 'C', 'B')
# Out:
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from A to C
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
