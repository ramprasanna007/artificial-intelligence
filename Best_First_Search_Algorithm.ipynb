# %% [markdown]
# <a href="https://colab.research.google.com/github/ramprasanna007/artificial-intelligence/blob/main/Best_First_Search_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Best First Search

graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': ['G'],
    'E': ['G'],
    'F': ['G'],
    'G': []
}

heuristic = {
    'A': 6,
    'B': 4,
    'C': 5,
    'D': 2,
    'E': 3,
    'F': 4,
    'G': 0
}

def best_first_search(start, goal):
    open_list = [start]
    visited = []

    while open_list:
        # Select node with lowest heuristic
        current = min(open_list, key=lambda node: heuristic[node])
        open_list.remove(current)

        print("Visiting:", current)

        if current == goal:
            print("Goal found!")
            return

        visited.append(current)

        for neighbor in graph[current]:
            if neighbor not in visited and neighbor not in open_list:
                open_list.append(neighbor)

best_first_search('A', 'G')
# Out:
# Visiting: A
# Visiting: B
# Visiting: D
# Visiting: G
# Goal found!
